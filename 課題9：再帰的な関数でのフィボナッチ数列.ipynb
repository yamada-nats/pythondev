# %%
import prognum

n = int(input("フィボナッチ数列　何番目の数値を求めますか："))

prognum.fibo(n)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 import prognum
#       3 n = input("フィボナッチ数列　何番目の数値を求めますか：")
# ----> 5 prognum.fibo(n)
#
# File c:\Users\natsuho_yamada\Documents\pythondev\prognum.py:8, in fibo(n)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# TypeError: '<' not supported between instances of 'str' and 'int'
